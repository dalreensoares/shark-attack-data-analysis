# %%
import pandas as pd

# %%
url = 'https://www.sharkattackfile.net/spreadsheets/GSAF5.xls'
df = pd.read_excel(url)
display(df)
# Out:
#              Date    Year        Type    Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked  AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked        USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked        USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked  AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked      INDIA        Maharashtra
# ...           ...     ...         ...        ...                ...
# 6964          NaN     NaN         NaN        NaN                NaN
# 6965          NaN     NaN         NaN        NaN                NaN
# 6966          NaN     NaN         NaN        NaN                NaN
# 6967          NaN     NaN         NaN        NaN                NaN
# 6968          NaN     NaN         NaN        NaN                NaN
#
#                               Location  Activity                 Name  Sex  \
# ...

# %% [markdown]
# We remove all rows with only NaN values to get rid of useless data. We have also removed columns that do not offer any useful information: pdf, href formula, href, source, unnamed:21, and unnamed:22.
#
# df.drop(columns=["href formula"], inplace = True)

# %%
df.drop(columns=["pdf"], inplace = True)
df.drop(columns=["href formula"], inplace = True)
df.drop(columns=["href"], inplace = True)
df.drop(columns=["source"], inplace = True)
df.drop(columns=["Unnamed: 21"], inplace = True)
df.drop(columns=["Unnamed: 22"], inplace = True)
df.drop(columns=["Unnamed: 11"], inplace = True)
df.drop(columns=["Case Number.1"], inplace = True)
df.drop(columns=["original order"], inplace = True)
df.drop(columns=["Case Number"], inplace = True)
df.dropna(how = "all")

# %%
# Out:
#              Date    Year        Type             Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked           AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked                 USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked                 USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked           AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# ...           ...     ...         ...                 ...                ...
# 6939  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6940  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6941    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6942    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6943    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
# ...

# %% [markdown]
# We make the columns names be lowercase and remove extra spaces..

# %%
df.columns = [i.replace(" ","").lower() for i in df.columns]
df.columns
# Out:
# Index(['date', 'year', 'type', 'country', 'state', 'location', 'activity',
#        'name', 'sex', 'age', 'injury', 'time', 'species'],
#       dtype='object')

# %%
We are now formating the sex and types columns so its elements are coherent and not redundant

# %%
sexes = {" M": "M", "M ": "M", "lli":"other", "M x 2": "M", "N":"M", ".":"other"}
df["sex"] = df["sex"].replace(sexes)
df["sex"].unique()
# Out:
# array(['F', 'M', nan, 'other'], dtype=object)

# %%
types = {" Provoked": "Provoked", "Questionable": "Unconfirmed", "?": "Unconfirmed", "Unverified":"Unconfirmed", "Under investigation": "Unconfirmed", "Invalid": "Unconfirmed", "Boat": "Watercraft"}
df["type"]=df["type"].replace(types)
df["type"].unique()
# Out:
# array(['Unprovoked', 'Provoked', 'Unconfirmed', 'Watercraft',
#        'Sea Disaster', nan], dtype=object)

# %%
df.fillna(0, inplace=True)

# %%
# Out:
# date        6004
# year         259
# type           6
# country      226
# state        903
# location    4515
# activity    1588
# name        5684
# sex            4
# age          170
# injury      4080
# time         411
# species     1676
# dtype: int64

# %%
df.iloc[414]
# Out:
# Date                                                    22-Feb-2020
# Year                                                         2020.0
# Type                                                     Unprovoked
# Country                                                 NEW ZEALAND
# State                                                  North Island
# Location                                              Pauanui Beach
# Activity                                                    Surfing
# Name                                                   Nick Minogue
# Sex                                                               M
# Age                                                              60
# Injury                               Minor injury, surfboard bitten
# Unnamed: 11                                                       N
# Time                                                          11h30
# Species                                                 White shark
# ...

# %%
print(df["Type"].unique())
# Out:
# ['Unprovoked' ' Provoked' 'Provoked' 'Questionable' 'Watercraft'
#  'Sea Disaster' nan '?' 'Unconfirmed' 'Unverified' 'Invalid'
#  'Under investigation' 'Boat']
